# %%
import numpy as np
import os

# %%
velodyne_dir = 'velodyne_points'
labels_dir = 'labels'
labels_norm_dir = 'normalized_labels'

# %%
def delete_file_if_exists(file_path):
    print('deleting file ' + file_path)
    
    try:
        os.remove(file_path)
    except Exception as e:
        print(f"\nFailed to process file {file_path}. Error: {e}")
        
        # print(f"File {file_path} not found, moving on.")

# %%
def remove_frame(directory, file_id):
    print()
    point_file = file_id + '.bin'
    label_file = file_id + '.txt'
    
    # Create file paths
    point_file_path = os.path.join(directory, velodyne_dir, point_file)
    label_file_path = os.path.join(directory, labels_dir, label_file)
    norm_label_file_path = os.path.join(directory, labels_norm_dir, label_file)

    # Delete files
    delete_file_if_exists(point_file_path)
    delete_file_if_exists(label_file_path)
    delete_file_if_exists(norm_label_file_path)

# %%
def delete_invalid_files(directory):
    bin_directory = os.path.join(directory, velodyne_dir)
    # List all files in the directory
    files = [f for f in os.listdir(bin_directory) if f.endswith('.bin')]
    # Check each bin file
    # for point_file in files:
    #     print('.', end='')

    #     # Get file id and label file
    #     file_id, extension = os.path.splitext(point_file)
    #     label_file = file_id + '.txt'

    #     # Create file paths
    #     point_file_path = os.path.join(directory, velodyne_dir, point_file)
    #     label_file_path = os.path.join(directory, labels_dir, label_file)
    #     norm_label_file_path = os.path.join(directory, labels_norm_dir, label_file)
        
    #     try:
    #         # Delete the velodyne and labels if...

    #         # The points file size is 0
    #         if os.path.getsize(point_file_path) == 0:
    #             print(f"\nFile {point_file_path} is empty")
    #             remove_frame(directory, file_id)
                
    #             # print('deleting file')
    #             # os.remove(point_file_path)
    #             # os.remove(label_file_path)
    #             # os.remove(norm_label_file_path)
                
    #         # The point cloud file dimensions are wrong
    #         # Load data from file
    #         data = np.fromfile(point_file_path, dtype=np.float32)
    #         # Check if the data size is divisible by 4
    #         if data.size % 4 != 0:
    #             print(f"\nFile {point_file_path} has incorrect dimensions: {data.size}")
    #             remove_frame(directory, file_id)
                
    #             # delete the point cloud file and the label
    #             # print('deleting file')
    #             # os.remove(point_file_path)
    #             # os.remove(label_file_path)
    #             # os.remove(norm_label_file_path)
    #     except Exception as e:
    #         print(f"\nFailed to process file {point_file}. Error: {e}")


    label_directory = os.path.join(directory, labels_dir)
    # List all files in the directory
    files = [f for f in os.listdir(label_directory) if f.endswith('.txt')]
    print('checking labels')
    to_delete = []
    
    # Check each label file
    for label_file in files:
        print('.', end='')
        # Get file id and label file
        file_id, extension = os.path.splitext(label_file)
        point_file = file_id + '.bin'

        # Create file paths
        point_file_path = os.path.join(directory, velodyne_dir, point_file)
        label_file_path = os.path.join(directory, labels_dir, label_file)
        norm_label_file_path = os.path.join(directory, labels_norm_dir, label_file)

        
        try:
            # Delete the velodyne and labels if...

            # The labels are empty
            with open(label_file_path, 'r') as file:
                lines = file.readlines()  # Read all lines in the file
                if len(lines) == 0:
                    # print(f"\nFile {label_file_path} has no labels")
                    # remove_frame(directory, file_id)
                    to_delete.append(file_id)

        except Exception as e:
            print(f"\nFailed to process file {label_file}. Error: {e}")

    for file_id in to_delete:
        remove_frame(directory, file_id)

# %%
# Specify the directory containing the .bin files
directory = '..\\data'
delete_invalid_files(directory)
# Out:
# checking labels
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# deleting file ..\data\velodyne_points\..\data\labels\006428.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006428.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006428.txt.bin'
# deleting file ..\data\labels\..\data\labels\006428.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006428.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006428.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006428.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006428.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006428.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006429.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006429.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006429.txt.bin'
# deleting file ..\data\labels\..\data\labels\006429.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006429.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006429.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006429.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006429.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006429.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006430.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006430.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006430.txt.bin'
# deleting file ..\data\labels\..\data\labels\006430.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006430.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006430.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006430.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006430.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006430.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006431.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006431.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006431.txt.bin'
# deleting file ..\data\labels\..\data\labels\006431.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006431.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006431.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006431.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006431.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006431.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006432.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006432.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006432.txt.bin'
# deleting file ..\data\labels\..\data\labels\006432.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006432.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006432.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006432.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006432.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006432.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006433.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006433.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006433.txt.bin'
# deleting file ..\data\labels\..\data\labels\006433.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006433.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006433.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006433.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006433.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006433.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006434.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006434.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006434.txt.bin'
# deleting file ..\data\labels\..\data\labels\006434.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006434.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006434.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006434.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006434.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006434.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006435.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006435.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006435.txt.bin'
# deleting file ..\data\labels\..\data\labels\006435.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006435.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006435.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006435.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006435.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006435.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000081.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000081.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000081.txt.bin'
# deleting file ..\data\labels\..\data\labels\000081.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000081.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000081.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000081.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000081.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000081.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000162.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000162.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000162.txt.bin'
# deleting file ..\data\labels\..\data\labels\000162.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000162.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000162.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000162.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000162.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000162.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000327.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000327.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000327.txt.bin'
# deleting file ..\data\labels\..\data\labels\000327.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000327.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000327.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000327.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000327.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000327.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000411.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000411.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000411.txt.bin'
# deleting file ..\data\labels\..\data\labels\000411.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000411.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000411.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000411.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000411.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000411.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000412.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000412.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000412.txt.bin'
# deleting file ..\data\labels\..\data\labels\000412.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000412.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000412.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000412.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000412.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000412.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000413.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000413.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000413.txt.bin'
# deleting file ..\data\labels\..\data\labels\000413.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000413.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000413.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000413.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000413.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000413.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000414.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000414.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000414.txt.bin'
# deleting file ..\data\labels\..\data\labels\000414.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000414.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000414.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000414.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000414.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000414.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000415.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000415.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000415.txt.bin'
# deleting file ..\data\labels\..\data\labels\000415.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000415.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000415.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000415.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000415.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000415.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000416.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000416.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000416.txt.bin'
# deleting file ..\data\labels\..\data\labels\000416.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\000416.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\000416.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\000416.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\000416.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\000416.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\000417.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\000417.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\000417.txt.bin'
# deleting file ..\data\labels\..\data\labels\000417.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\
txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006413.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006413.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006413.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006414.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006414.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006414.txt.bin'
# deleting file ..\data\labels\..\data\labels\006414.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006414.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006414.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006414.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006414.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006414.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006415.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006415.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006415.txt.bin'
# deleting file ..\data\labels\..\data\labels\006415.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006415.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006415.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006415.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006415.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006415.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006416.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006416.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006416.txt.bin'
# deleting file ..\data\labels\..\data\labels\006416.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006416.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006416.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006416.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006416.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006416.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006417.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006417.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006417.txt.bin'
# deleting file ..\data\labels\..\data\labels\006417.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006417.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006417.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006417.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006417.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006417.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006418.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006418.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006418.txt.bin'
# deleting file ..\data\labels\..\data\labels\006418.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006418.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006418.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006418.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006418.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006418.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006419.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006419.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006419.txt.bin'
# deleting file ..\data\labels\..\data\labels\006419.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006419.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006419.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006419.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006419.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006419.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006420.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006420.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006420.txt.bin'
# deleting file ..\data\labels\..\data\labels\006420.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006420.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006420.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006420.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006420.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006420.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006421.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006421.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006421.txt.bin'
# deleting file ..\data\labels\..\data\labels\006421.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006421.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006421.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006421.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006421.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006421.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006422.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006422.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006422.txt.bin'
# deleting file ..\data\labels\..\data\labels\006422.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006422.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006422.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006422.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006422.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006422.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006423.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006423.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006423.txt.bin'
# deleting file ..\data\labels\..\data\labels\006423.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006423.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006423.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006423.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006423.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006423.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006424.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006424.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006424.txt.bin'
# deleting file ..\data\labels\..\data\labels\006424.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006424.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006424.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006424.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006424.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006424.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006425.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006425.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006425.txt.bin'
# deleting file ..\data\labels\..\data\labels\006425.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006425.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006425.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006425.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006425.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006425.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006426.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006426.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006426.txt.bin'
# deleting file ..\data\labels\..\data\labels\006426.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006426.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006426.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006426.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006426.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006426.txt.txt'
#
# deleting file ..\data\velodyne_points\..\data\labels\006427.txt.bin
#
# Failed to process file ..\data\velodyne_points\..\data\labels\006427.txt.bin. Error: [WinError 3] The system cannot find the path specified: '..\\data\\velodyne_points\\..\\data\\labels\\006427.txt.bin'
# deleting file ..\data\labels\..\data\labels\006427.txt.txt
#
# Failed to process file ..\data\labels\..\data\labels\006427.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\labels\\..\\data\\labels\\006427.txt.txt'
# deleting file ..\data\normalized_labels\..\data\labels\006427.txt.txt
#
# Failed to process file ..\data\normalized_labels\..\data\labels\006427.txt.txt. Error: [WinError 3] The system cannot find the path specified: '..\\data\\normalized_labels\\..\\data\\labels\\006427.txt.txt'

# %%
# # Specify the directory containing the .bin files
# directory = '..\\data\\split_arcs\\training\\velodyne'
# delete_invalid_files(directory)

# %%
# # Specify the directory containing the .bin files
# directory = '..\\data\\split_arcs\\testing\\velodyne'
# delete_invalid_files(directory)
